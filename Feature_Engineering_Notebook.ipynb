# %% [markdown]
# # Feature Engineering Notebook
# This notebook creates model-ready features from the cleaned wage dataset.

# %%
import numpy as np
import pandas as pd

# %%
data_path = 'data/cleaned_wage_data.csv'
df = pd.read_csv(data_path)
df.head()
# Out:
#    age  education_years education_level         occupation       industry  \
# 0   25               16       Bachelors       Data Analyst     Technology
# 1   31               18         Masters  Software Engineer     Technology
# 2   42               12     High School   Machine Operator  Manufacturing
# 3   37               14       Associate              Nurse     Healthcare
# 4   29               16       Bachelors  Financial Analyst        Finance
#
#    hours_per_week   wage
# 0              40  58000
# 1              45  92000
# 2              50  47000
# 3              36  76000
# 4              42  81000

# %% [markdown]
# ## Create Experience Proxy and Log Wage
# Adjust column names below if your dataset uses different labels.

# %%
age_col = 'age'
education_years_col = 'education_years'
wage_col = 'wage'

if age_col in df.columns and education_years_col in df.columns:
    df['experience_proxy'] = df[age_col] - df[education_years_col]
    df['experience_proxy'] = df['experience_proxy'].clip(lower=0)

if wage_col in df.columns:
    df['log_wage'] = np.log1p(df[wage_col])

df[[col for col in ['experience_proxy', 'log_wage'] if col in df.columns]].head()
# Out:
#    experience_proxy   log_wage
# 0                 9  10.968216
# 1                13  11.429555
# 2                30  10.757924
# 3                23  11.238502
# 4                13  11.302217

# %% [markdown]
# ## Handle Sparse Categories

# %%
categorical_cols = df.select_dtypes(exclude=[np.number]).columns
min_frequency = 0.01

for col in categorical_cols:
    freq = df[col].value_counts(normalize=True)
    rare_values = freq[freq < min_frequency].index
    df[col] = df[col].replace(rare_values, 'Other')

df[categorical_cols].nunique().sort_values(ascending=False).head(10)
# Out:
# occupation         10
# industry            8
# education_level     7
# dtype: int64

# %% [markdown]
# ## Encode Features

# %%
target_col = 'log_wage' if 'log_wage' in df.columns else 'wage'
feature_df = df.drop(columns=[target_col], errors='ignore')

encoded_df = pd.get_dummies(feature_df, drop_first=True)

if target_col in df.columns:
    encoded_df[target_col] = df[target_col]

print('Encoded shape:', encoded_df.shape)
encoded_df.head()
# Out:
# Encoded shape: (10, 28)
#    age  education_years  hours_per_week   wage  experience_proxy  \
# 0   25               16              40  58000                 9
# 1   31               18              45  92000                13
# 2   42               12              50  47000                30
# 3   37               14              36  76000                23
# 4   29               16              42  81000                13
#
#    education_level_Bachelors  education_level_Doctorate  \
# 0                       True                      False
# 1                      False                      False
# 2                      False                      False
# 3                      False                      False
# 4                       True                      False
#
#    education_level_High School  education_level_Masters  \
# 0                        False                    False
# 1                        False                     True
# 2                         True                    False
# 3                        False                    False
# 4                        False                    False
#
#    education_level_Some College  ...  occupation_Sales Representative  \
# 0                         False  ...                            False
# 1                         False  ...                            False
# 2                         False  ...                            False
# 3                         False  ...                            False
# 4                         False  ...                            False
#
#    occupation_Software Engineer  industry_Finance  industry_Government  \
# 0                         False             False                False
# 1                          True             False                False
# 2                         False             False                False
# 3                         False             False                False
# 4                         False              True                False
#
#    industry_Healthcare  industry_Manufacturing  \
# 0                False                   False
# 1                False                   False
# 2                False                    True
# 3                 True                   False
# 4                False                   False
#
#    industry_Professional Services  industry_Retail  industry_Technology  \
# 0                           False            False                 True
# 1                           False            False                 True
# 2                           False            False                False
# 3                           False            False                False
# 4                           False            False                False
#
#     log_wage
# 0  10.968216
# 1  11.429555
# 2  10.757924
# 3  11.238502
# 4  11.302217
#
# [5 rows x 28 columns]

# %%
output_path = 'data/engineered_wage_data.csv'
encoded_df.to_csv(output_path, index=False)
print(f'Saved engineered data to {output_path}')
# Out:
# Saved engineered data to data/engineered_wage_data.csv
